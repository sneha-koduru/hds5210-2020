# %% [markdown]
# # Week 11 Exercises
#
# _McKinney 7.2, 11.1_
#
# The general activity that we are doing in this week's exercise is to explore and try to understand a particular data set.  In this case, it is
#
# 1. Read in the data file and filter down to only looking at MO hospitals
# 2. Aggregate by Hospital: sum the Denominator, use min Start Date, use max End Date  (watch for rows with no Denominator value!)
# 3. Calculate the average per day across that entire span
# 4. Histogram
# 5. Rank and find the hospital with the most

# %% [markdown]
# ## STEP 1 - Read and Filter
#
# <img src="images/step1.png" alt="Read and Filter Output" style="width: 500px; float: right; margin-left: 20px; border: 1px solid">
#
# In the first step, read in the data file from the data directory `/data/complications_all.csv`.  It is a CSV file and Pandas should read it in just fine.  Explore the file so that you understand the columns and values.  At the end of this step, create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# A screenshot is included for reference.

# %%
import pandas as pd

data = pd.DataFrame(pd.read_csv('complications_all.csv'))

# This is just to show you the name to use for the variable you need to create for this step to pass.
mo_hospitals = data[data['State'] == "MO"]

# Put your code below and make sure that you reassign `mo_hospitals` 
# to have the contents described in the instructions.

# %%
mo_hospitals.head()
# Out:
#       Facility ID          Facility Name        Address    City State  \
# 45534      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45535      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45536      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45537      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45538      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
#
#        ZIP Code County Name    Phone Number     Measure ID  \
# 45534     64804      JASPER  (417) 781-2727  COMP_HIP_KNEE
# 45535     64804      JASPER  (417) 781-2727    MORT_30_AMI
# 45536     64804      JASPER  (417) 781-2727   MORT_30_CABG
# 45537     64804      JASPER  (417) 781-2727   MORT_30_COPD
# 45538     64804      JASPER  (417) 781-2727     MORT_30_HF
#
#                                             Measure Name  \
# 45534  Rate of complications for hip/knee replacement...
# 45535               Death rate for heart attack patients
# 45536               Death rate for CABG surgery patients
# 45537                       Death rate for COPD patients
# 45538              Death rate for heart failure patients
#
#                       Compared to National Denominator Score Lower Estimate  \
# 45534  No Different Than the National Rate          26   2.5            1.4
# 45535  No Different Than the National Rate         175  13.9           11.0
# 45536  No Different Than the National Rate          91   2.5            1.2
# 45537  No Different Than the National Rate         326   8.5            6.5
# 45538  No Different Than the National Rate         461  13.1           10.7
#
#       Higher Estimate  Footnote  Start Date    End Date
# 45534             4.2       NaN  04/01/2015  03/31/2018
# 45535            16.9       NaN  07/01/2015  06/30/2018
# 45536             5.1       NaN  07/01/2015  06/30/2018
# 45537            10.9       NaN  07/01/2015  06/30/2018
# 45538            15.9       NaN  07/01/2015  06/30/2018

# %%
# These assertions will help make sure that you're on the right track.
assert(mo_hospitals['State'].unique() == ['MO'])
assert(mo_hospitals.shape == (2133,18))

# %% [markdown]
# ## STEP 2 - Transform and Aggregate
#
# <img src="images/step2.png" alt="Transforma and Aggregate Output" style="width: 500px; float: right; margin-left: 20px; border: 1px solid">
#
# In the next step, we need to aggregate the results by hospital.  There are some key fields that we want to summarize, though:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
# A screenshot is included for reference.

# %%
# This is just to show you the name to use for the variable you need to create for this step to pass.



from IPython.display import display
pd.options.display.max_rows
pd.set_option('display.max_rows', None)



# Put your code below and make sure that you reassign `mo_summary` 
# to have the contents described in the instructions.
mo_hospitals=mo_hospitals[mo_hospitals['Denominator']!='Not Available']

mo_summary = pd.DataFrame(index=hospitals,columns=["number", "start_date", "end_date"])
mo_hospital_list = mo_hospitals.groupby(['Facility Name'])

hospitals = mo_hospitals['Facility Name'].unique()

##  mo_summary[hospital]['number'] = mo_hospitals.groupby(['Facility Name']).sum()[['']]


for hospital in hospitals:
    n = pd.to_numeric(mo_hospital_list.get_group(hospital)['Denominator']).sum()
    mo_summary.at[hospital, "start_date"] = pd.to_datetime(mo_hospital_list.get_group(hospital)['Start Date']).min().date()
    mo_summary.at[hospital, "end_date"] = pd.to_datetime(mo_hospital_list.get_group(hospital)['End Date']).max().date()
    mo_summary.at[hospital, "number"] = n
    
display(mo_summary)
# Out:
#                                                    number  start_date  \
# MERCY HOSPITAL JOPLIN                               29977  2015-04-01
# COOPER COUNTY COMMUNITY HOSPITAL                      697  2015-07-01
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES            23443  2015-04-01
# MOSAIC LIFE CARE AT ST JOSEPH                       54860  2015-04-01
# BOTHWELL REGIONAL HEALTH CENTER                     14717  2015-04-01
# SSM HEALTH ST. MARY'S HOSPITAL - JEFFERSON CITY     20531  2015-04-01
# PHELPS HEALTH                                       16014  2015-04-01
# MERCY HOSPITAL ST LOUIS                             68665  2015-04-01
# NORTHEAST REGIONAL MEDICAL CENTER                    7736  2015-04-01
# MERCY HOSPITAL JEFFERSON                            23770  2015-04-01
# TEXAS COUNTY MEMORIAL HOSPITAL                       3609  2015-07-01
# HANNIBAL REGIONAL HOSPITAL                          17532  2015-04-01
# RESEARCH MEDICAL CENTER                             32514  2015-04-01
# BARNES JEWISH HOSPITAL                             131313  2015-04-01
# BATES COUNTY MEMORIAL HOSPITAL                       3117  2015-07-01
# COX MEDICAL CENTERS                                 69169  2015-04-01
# CAPITAL REGION MEDICAL CENTER                       17598  2015-04-01
# TRUMAN MEDICAL CENTER HOSPITAL HILL                 11725  2015-07-01
# KANSAS CITY VA MEDICAL CENTER                         942  2015-07-01
# MOSAIC MEDICAL CENTER - MARYVILLE                    2477  2015-04-01
# MERCY HOSPITAL WASHINGTON                           14175  2015-04-01
# CAMERON REGIONAL MEDICAL CENTER                      6066  2015-04-01
# MERCY HOSPITAL LEBANON                               5665  2015-04-01
# NEVADA REGIONAL MEDICAL CENTER                       2001  2015-07-01
# SAINT LUKES NORTH HOSPITAL                          15695  2015-04-01
# SSM HEALTH ST. MARY'S HOSPITAL-AUDRAIN               5543  2015-04-01
# MERCY HOSPITAL SPRINGFIELD                          81264  2015-04-01
# BOONE HOSPITAL CENTER                               63099  2015-04-01
# PEMISCOT COUNTY MEMORIAL HOSPITAL                    3891  2015-07-01
# MOBERLY REGIONAL MEDICAL CENTER                      3860  2015-04-01
# MERCY HOSPITAL SOUTH                                62487  2015-04-01
# OZARKS MEDICAL CENTER                               13697  2015-04-01
# POPLAR BLUFF VA MEDICAL CENTER                        226  2015-07-01
# SSM HEALTH ST CLARE HOSPITAL - FENTON               28080  2015-04-01
# ST JOSEPH MEDICAL CENTER                            22538  2015-04-01
# SSM HEALTH ST MARY'S HOSPITAL - ST LOUIS            26998  2015-04-01
# COX MEDICAL CENTER BRANSON                          16633  2015-04-01
# CENTERPOINT MEDICAL CENTER                          35106  2015-04-01
# NORTH KANSAS CITY HOSPITAL                          61446  2015-04-01
# WESTERN MISSOURI MEDICAL CENTER                      7254  2015-04-01
# ST LOUIS-JOHN COCHRAN VA MEDICAL CENTER              1062  2015-07-01
# TRUMAN MEDICAL CENTER LAKEWOOD                       4297  2015-04-01
# SSM HEALTH DEPAUL HOSPITAL ST LOUIS                 51585  2015-04-01
# SSM HEALTH SAINT LOUIS UNIVERSITY HOSPITAL          29630  2015-07-01
# MISSOURI BAPTIST MEDICAL CENTER                     62915  2015-04-01
# SOUTHEASTHEALTH                                     33762  2015-04-01
# MISSOURI DELTA MEDICAL CENTER                       11091  2015-04-01
# POPLAR BLUFF REGIONAL MEDICAL CENTER                25166  2015-04-01
# FREEMAN HEALTH SYSTEM - FREEMAN WEST                53519  2015-04-01
# ST LUKES HOSPITAL OF KANSAS CITY                    58487  2015-04-01
# UNIVERSITY OF MISSOURI HEALTH CARE                  56493  2015-04-01
# FITZGIBBON HOSPITAL                                  3669  2015-04-01
# SOUTHEASTHEALTH CENTER OF STODDARD COUNTY            2810  2015-07-01
# BARNES-JEWISH WEST COUNTY HOSPITAL                   9622  2015-04-01
# PARKLAND HEALTH CENTER                               9731  2015-04-01
# GOLDEN VALLEY MEMORIAL HOSPITAL                      6360  2015-04-01
# ST LUKE'S DES PERES HOSPITAL                        13142  2015-04-01
# LIBERTY HOSPITAL                                    24716  2015-04-01
# ST LUKES HOSPITAL                                   52987  2015-04-01
# CHRISTIAN HOSPITAL NORTHEAST-NORTHWEST              31846  2015-04-01
# SAINT FRANCIS MEDICAL CENTER                        45199  2015-04-01
# LAKE REGIONAL HEALTH SYSTEM                         16028  2015-04-01
# LEE'S SUMMIT MEDICAL CENTER                         11806  2015-04-01
# BARNES-JEWISH ST PETERS HOSPITAL                    15668  2015-04-01
# ST MARY'S MEDICAL CENTER                            13610  2015-04-01
# CITIZENS MEMORIAL HOSPITAL                           7529  2015-04-01
# SSM HEALTH SAINT JOSEPH HOSPITAL-LAKE SAINT LOUIS   24239  2015-04-01
# FULTON MEDICAL CENTER LLC                             184  2016-07-01
# ST ALEXIUS HOSPITAL                                  5712  2015-07-01
# BELTON REGIONAL MEDICAL CENTER                       9270  2015-04-01
# SAINT LUKE'S EAST HOSPITAL                          35865  2015-04-01
# PROGRESS WEST HOSPITAL                               5931  2015-04-01
# COLUMBIA MO VA MEDICAL CENTER                         890  2015-07-01
# ELLETT MEMORIAL HOSPITAL                               97  2015-07-01
# MADISON MEDICAL CENTER                                103  2015-07-01
# COMMUNITY HOSPITAL ASSOCIATION                        184  2015-07-01
# PUTNAM COUNTY MEMORIAL HOSPITAL                        71  2015-07-01
# SULLIVAN COUNTY MEMORIAL HOSPITAL                      40  2015-07-01
# PERSHING MEMORIAL HOSPITAL                            179  2015-07-01
# WASHINGTON COUNTY MEMORIAL HOSPITAL                   220  2015-07-01
# WRIGHT MEMORIAL HOSPITAL                              198  2015-07-01
# SCOTLAND COUNTY  HOSPITAL                             117  2015-07-01
# PERRY COUNTY MEMORIAL HOSPITAL                        488  2015-04-01
# HARRISON COUNTY COMMUNITY HOSPITAL                    167  2015-07-01
# MACON COUNTY SAMARITAN MEMORIAL HOSPITAL              264  2015-04-01
# HERMANN AREA DISTRICT HOSPITAL                        119  2015-07-01
# MERCY HOSPITAL AURORA                                  96  2015-07-01
# MERCY HOSPITAL CASSVILLE                               98  2015-07-01
# SALEM MEMORIAL DISTRICT HOSPITAL                      339  2015-07-01
# MERCY HOSPITAL LINCOLN                                161  2015-07-01
# LAFAYETTE REGIONAL HEALTH CENTER                      194  2015-07-01
# HEDRICK MEDICAL CENTER                                359  2015-07-01
# EXCELSIOR SPRINGS HOSPITAL                             47  2015-07-01
# CEDAR COUNTY MEMORIAL HOSPITAL                         53  2015-07-01
# CASS REGIONAL MEDICAL CENTER                          289  2015-04-01
# COX BARTON COUNTY HOSPITAL                            201  2015-04-01
# RAY COUNTY MEMORIAL HOSPITAL                          204  2015-07-01
# MOSAIC MEDICAL CENTER ALBANY                          117  2015-07-01
# COX MONETT HOSPITAL                                    98  2015-07-01
# STE GENEVIEVE COUNTY MEMORIAL HOSPITAL                291  2015-04-01
# FREEMAN NEOSHO HOSPITAL                               258  2015-07-01
# CARROLL COUNTY MEMORIAL HOSPITAL                       81  2015-07-01
# PIKE COUNTY MEMORIAL HOSPITAL                         211  2015-07-01
# I-70 COMMUNITY HOSPITAL                                26  2015-07-01
# MERCY ST FRANCIS HOSPITAL                              60  2015-07-01
# IRON COUNTY MEDICAL CENTER                             99  2015-07-01
# MISSOURI BAPTIST SULLIVAN HOSPITAL                    275  2015-07-01
# MERCY HOSPITAL CARTHAGE                               153  2015-07-01
#
#                                                      end_date
# MERCY HOSPITAL JOPLIN                              2018-06-30
# COOPER COUNTY COMMUNITY HOSPITAL                   2018-06-30
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES           2018-06-30
# MOSAIC LIFE CARE AT ST JOSEPH                      2018-06-30
# BOTHWELL REGIONAL HEALTH CENTER                    2018-06-30
# SSM HEALTH ST. MARY'S HOSPITAL - JEFFERSON CITY    2018-06-30
# PHELPS HEALTH                                      2018-06-30
# MERCY HOSPITAL ST LOUIS                            2018-06-30
# NORTHEAST REGIONAL MEDICAL CENTER                  2018-06-30
# MERCY HOSPITAL JEFFERSON                           2018-06-30
# TEXAS COUNTY MEMORIAL HOSPITAL                     2018-06-30
# HANNIBAL REGIONAL HOSPITAL                         2018-06-30
# RESEARCH MEDICAL CENTER                            2018-06-30
# BARNES JEWISH HOSPITAL                             2018-06-30
# BATES COUNTY MEMORIAL HOSPITAL                     2018-06-30
# COX MEDICAL CENTERS                                2018-06-30
# CAPITAL REGION MEDICAL CENTER                      2018-06-30
# TRUMAN MEDICAL CENTER HOSPITAL HILL                2018-06-30
# KANSAS CITY VA MEDICAL CENTER                      2018-06-30
# MOSAIC MEDICAL CENTER - MARYVILLE                  2018-06-30
# MERCY HOSPITAL WASHINGTON                          2018-06-30
# CAMERON REGIONAL MEDICAL CENTER                    2018-06-30
# MERCY HOSPITAL LEBANON                             2018-06-30
# NEVADA REGIONAL MEDICAL CENTER                     2018-06-30
# SAINT LUKES NORTH HOSPITAL                         2018-06-30
# SSM HEALTH ST. MARY'S HOSPITAL-AUDRAIN             2018-06-30
# MERCY HOSPITAL SPRINGFIELD                         2018-06-30
# BOONE HOSPITAL CENTER                              2018-06-30
# PEMISCOT COUNTY MEMORIAL HOSPITAL                  2018-06-30
# MOBERLY REGIONAL MEDICAL CENTER                    2018-06-30
# MERCY HOSPITAL SOUTH                               2018-06-30
# OZARKS MEDICAL CENTER                              2018-06-30
# POPLAR BLUFF VA MEDICAL CENTER                     2018-06-30
# SSM HEALTH ST CLARE HOSPITAL - FENTON              2018-06-30
# ST JOSEPH MEDICAL CENTER                           2018-06-30
# SSM HEALTH ST MARY'S HOSPITAL - ST LOUIS           2018-06-30
# COX MEDICAL CENTER BRANSON                         2018-06-30
# CENTERPOINT MEDICAL CENTER                         2018-06-30
# NORTH KANSAS CITY HOSPITAL                         2018-06-30
# WESTERN MISSOURI MEDICAL CENTER                    2018-06-30
# ST LOUIS-JOHN COCHRAN VA MEDICAL CENTER            2018-06-30
# TRUMAN MEDICAL CENTER LAKEWOOD                     2018-06-30
# SSM HEALTH DEPAUL HOSPITAL ST LOUIS                2018-06-30
# SSM HEALTH SAINT LOUIS UNIVERSITY HOSPITAL         2018-06-30
# MISSOURI BAPTIST MEDICAL CENTER                    2018-06-30
# SOUTHEASTHEALTH                                    2018-06-30
# MISSOURI DELTA MEDICAL CENTER                      2018-06-30
# POPLAR BLUFF REGIONAL MEDICAL CENTER               2018-06-30
# FREEMAN HEALTH SYSTEM - FREEMAN WEST               2018-06-30
# ST LUKES HOSPITAL OF KANSAS CITY                   2018-06-30
# UNIVERSITY OF MISSOURI HEALTH CARE                 2018-06-30
# FITZGIBBON HOSPITAL                                2018-06-30
# SOUTHEASTHEALTH CENTER OF STODDARD COUNTY          2018-06-30
# BARNES-JEWISH WEST COUNTY HOSPITAL                 2018-06-30
# PARKLAND HEALTH CENTER                             2018-06-30
# GOLDEN VALLEY MEMORIAL HOSPITAL                    2018-06-30
# ST LUKE'S DES PERES HOSPITAL                       2018-06-30
# LIBERTY HOSPITAL                                   2018-06-30
# ST LUKES HOSPITAL                                  2018-06-30
# CHRISTIAN HOSPITAL NORTHEAST-NORTHWEST             2018-06-30
# SAINT FRANCIS MEDICAL CENTER                       2018-06-30
# LAKE REGIONAL HEALTH SYSTEM                        2018-06-30
# LEE'S SUMMIT MEDICAL CENTER                        2018-06-30
# BARNES-JEWISH ST PETERS HOSPITAL                   2018-06-30
# ST MARY'S MEDICAL CENTER                           2018-06-30
# CITIZENS MEMORIAL HOSPITAL                         2018-06-30
# SSM HEALTH SAINT JOSEPH HOSPITAL-LAKE SAINT LOUIS  2018-06-30
# FULTON MEDICAL CENTER LLC                          2018-06-30
# ST ALEXIUS HOSPITAL                                2018-06-30
# BELTON REGIONAL MEDICAL CENTER                     2018-06-30
# SAINT LUKE'S EAST HOSPITAL                         2018-06-30
# PROGRESS WEST HOSPITAL                             2018-06-30
# COLUMBIA MO VA MEDICAL CENTER                      2018-06-30
# ELLETT MEMORIAL HOSPITAL                           2018-06-30
# MADISON MEDICAL CENTER                             2018-06-30
# COMMUNITY HOSPITAL ASSOCIATION                     2018-06-30
# PUTNAM COUNTY MEMORIAL HOSPITAL                    2018-06-30
# SULLIVAN COUNTY MEMORIAL HOSPITAL                  2018-06-30
# PERSHING MEMORIAL HOSPITAL                         2018-06-30
# WASHINGTON COUNTY MEMORIAL HOSPITAL                2018-06-30
# WRIGHT MEMORIAL HOSPITAL                           2018-06-30
# SCOTLAND COUNTY  HOSPITAL                          2018-06-30
# PERRY COUNTY MEMORIAL HOSPITAL                     2018-06-30
# HARRISON COUNTY COMMUNITY HOSPITAL                 2018-06-30
# MACON COUNTY SAMARITAN MEMORIAL HOSPITAL           2018-06-30
# HERMANN AREA DISTRICT HOSPITAL                     2018-06-30
# MERCY HOSPITAL AURORA                              2018-06-30
# MERCY HOSPITAL CASSVILLE                           2018-06-30
# SALEM MEMORIAL DISTRICT HOSPITAL                   2018-06-30
# MERCY HOSPITAL LINCOLN                             2018-06-30
# LAFAYETTE REGIONAL HEALTH CENTER                   2018-06-30
# HEDRICK MEDICAL CENTER                             2018-06-30
# EXCELSIOR SPRINGS HOSPITAL                         2018-06-30
# CEDAR COUNTY MEMORIAL HOSPITAL                     2018-06-30
# CASS REGIONAL MEDICAL CENTER                       2018-06-30
# COX BARTON COUNTY HOSPITAL                         2018-06-30
# RAY COUNTY MEMORIAL HOSPITAL                       2018-06-30
# MOSAIC MEDICAL CENTER ALBANY                       2018-06-30
# COX MONETT HOSPITAL                                2018-06-30
# STE GENEVIEVE COUNTY MEMORIAL HOSPITAL             2018-06-30
# FREEMAN NEOSHO HOSPITAL                            2018-06-30
# CARROLL COUNTY MEMORIAL HOSPITAL                   2018-06-30
# PIKE COUNTY MEMORIAL HOSPITAL                      2018-06-30
# I-70 COMMUNITY HOSPITAL                            2018-06-30
# MERCY ST FRANCIS HOSPITAL                          2018-06-30
# IRON COUNTY MEDICAL CENTER                         2018-06-30
# MISSOURI BAPTIST SULLIVAN HOSPITAL                 2018-06-30
# MERCY HOSPITAL CARTHAGE                            2018-06-30

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,3))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)

# %% [markdown]
# ## STEP 3: Average Per Day
#
# <img src="images/step3.png" alt="Average per Day" style="width: 500px; margin-left: 20px; float: right; border: 1px solid">
#
#
# The next step, now that we have a start date, end date, and total patients for each day is to calculate how many patients on average per day this represents.  You will need to calculate the number of days between the start date and end date, and then the average as total patients divided by number of days.
#
# Your final output should still be the variable `mo_summary`, and it will need to have two additional columns: `days` and `per_day`.
#
# A screenshot is included for reference.

# %%
# Put your code below and make sure that you add new columns to `mo_summary` 
# to have the contents described in the instructions.


mo_summary['days'] = ((mo_summary['end_date']) - (mo_summary['start_date'])).dt.days
mo_summary['per_day'] = (mo_summary['number']) / (mo_summary['days'])
display(mo_summary)
# Out:
#                                                    number  start_date  \
# MERCY HOSPITAL JOPLIN                               29977  2015-04-01
# COOPER COUNTY COMMUNITY HOSPITAL                      697  2015-07-01
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES            23443  2015-04-01
# MOSAIC LIFE CARE AT ST JOSEPH                       54860  2015-04-01
# BOTHWELL REGIONAL HEALTH CENTER                     14717  2015-04-01
# SSM HEALTH ST. MARY'S HOSPITAL - JEFFERSON CITY     20531  2015-04-01
# PHELPS HEALTH                                       16014  2015-04-01
# MERCY HOSPITAL ST LOUIS                             68665  2015-04-01
# NORTHEAST REGIONAL MEDICAL CENTER                    7736  2015-04-01
# MERCY HOSPITAL JEFFERSON                            23770  2015-04-01
# TEXAS COUNTY MEMORIAL HOSPITAL                       3609  2015-07-01
# HANNIBAL REGIONAL HOSPITAL                          17532  2015-04-01
# RESEARCH MEDICAL CENTER                             32514  2015-04-01
# BARNES JEWISH HOSPITAL                             131313  2015-04-01
# BATES COUNTY MEMORIAL HOSPITAL                       3117  2015-07-01
# COX MEDICAL CENTERS                                 69169  2015-04-01
# CAPITAL REGION MEDICAL CENTER                       17598  2015-04-01
# TRUMAN MEDICAL CENTER HOSPITAL HILL                 11725  2015-07-01
# KANSAS CITY VA MEDICAL CENTER                         942  2015-07-01
# MOSAIC MEDICAL CENTER - MARYVILLE                    2477  2015-04-01
# MERCY HOSPITAL WASHINGTON                           14175  2015-04-01
# CAMERON REGIONAL MEDICAL CENTER                      6066  2015-04-01
# MERCY HOSPITAL LEBANON                               5665  2015-04-01
# NEVADA REGIONAL MEDICAL CENTER                       2001  2015-07-01
# SAINT LUKES NORTH HOSPITAL                          15695  2015-04-01
# SSM HEALTH ST. MARY'S HOSPITAL-AUDRAIN               5543  2015-04-01
# MERCY HOSPITAL SPRINGFIELD                          81264  2015-04-01
# BOONE HOSPITAL CENTER                               63099  2015-04-01
# PEMISCOT COUNTY MEMORIAL HOSPITAL                    3891  2015-07-01
# MOBERLY REGIONAL MEDICAL CENTER                      3860  2015-04-01
# MERCY HOSPITAL SOUTH                                62487  2015-04-01
# OZARKS MEDICAL CENTER                               13697  2015-04-01
# POPLAR BLUFF VA MEDICAL CENTER                        226  2015-07-01
# SSM HEALTH ST CLARE HOSPITAL - FENTON               28080  2015-04-01
# ST JOSEPH MEDICAL CENTER                            22538  2015-04-01
# SSM HEALTH ST MARY'S HOSPITAL - ST LOUIS            26998  2015-04-01
# COX MEDICAL CENTER BRANSON                          16633  2015-04-01
# CENTERPOINT MEDICAL CENTER                          35106  2015-04-01
# NORTH KANSAS CITY HOSPITAL                          61446  2015-04-01
# WESTERN MISSOURI MEDICAL CENTER                      7254  2015-04-01
# ST LOUIS-JOHN COCHRAN VA MEDICAL CENTER              1062  2015-07-01
# TRUMAN MEDICAL CENTER LAKEWOOD                       4297  2015-04-01
# SSM HEALTH DEPAUL HOSPITAL ST LOUIS                 51585  2015-04-01
# SSM HEALTH SAINT LOUIS UNIVERSITY HOSPITAL          29630  2015-07-01
# MISSOURI BAPTIST MEDICAL CENTER                     62915  2015-04-01
# SOUTHEASTHEALTH                                     33762  2015-04-01
# MISSOURI DELTA MEDICAL CENTER                       11091  2015-04-01
# POPLAR BLUFF REGIONAL MEDICAL CENTER                25166  2015-04-01
# FREEMAN HEALTH SYSTEM - FREEMAN WEST                53519  2015-04-01
# ST LUKES HOSPITAL OF KANSAS CITY                    58487  2015-04-01
# UNIVERSITY OF MISSOURI HEALTH CARE                  56493  2015-04-01
# FITZGIBBON HOSPITAL                                  3669  2015-04-01
# SOUTHEASTHEALTH CENTER OF STODDARD COUNTY            2810  2015-07-01
# BARNES-JEWISH WEST COUNTY HOSPITAL                   9622  2015-04-01
# PARKLAND HEALTH CENTER                               9731  2015-04-01
# GOLDEN VALLEY MEMORIAL HOSPITAL                      6360  2015-04-01
# ST LUKE'S DES PERES HOSPITAL                        13142  2015-04-01
# LIBERTY HOSPITAL                                    24716  2015-04-01
# ST LUKES HOSPITAL                                   52987  2015-04-01
# CHRISTIAN HOSPITAL NORTHEAST-NORTHWEST              31846  2015-04-01
# SAINT FRANCIS MEDICAL CENTER                        45199  2015-04-01
# LAKE REGIONAL HEALTH SYSTEM                         16028  2015-04-01
# LEE'S SUMMIT MEDICAL CENTER                         11806  2015-04-01
# BARNES-JEWISH ST PETERS HOSPITAL                    15668  2015-04-01
# ST MARY'S MEDICAL CENTER                            13610  2015-04-01
# CITIZENS MEMORIAL HOSPITAL                           7529  2015-04-01
# SSM HEALTH SAINT JOSEPH HOSPITAL-LAKE SAINT LOUIS   24239  2015-04-01
# FULTON MEDICAL CENTER LLC                             184  2016-07-01
# ST ALEXIUS HOSPITAL                                  5712  2015-07-01
# BELTON REGIONAL MEDICAL CENTER                       9270  2015-04-01
# SAINT LUKE'S EAST HOSPITAL                          35865  2015-04-01
# PROGRESS WEST HOSPITAL                               5931  2015-04-01
# COLUMBIA MO VA MEDICAL CENTER                         890  2015-07-01
# ELLETT MEMORIAL HOSPITAL                               97  2015-07-01
# MADISON MEDICAL CENTER                                103  2015-07-01
# COMMUNITY HOSPITAL ASSOCIATION                        184  2015-07-01
# PUTNAM COUNTY MEMORIAL HOSPITAL                        71  2015-07-01
# SULLIVAN COUNTY MEMORIAL HOSPITAL                      40  2015-07-01
# PERSHING MEMORIAL HOSPITAL                            179  2015-07-01
# WASHINGTON COUNTY MEMORIAL HOSPITAL                   220  2015-07-01
# WRIGHT MEMORIAL HOSPITAL                              198  2015-07-01
# SCOTLAND COUNTY  HOSPITAL                             117  2015-07-01
# PERRY COUNTY MEMORIAL HOSPITAL                        488  2015-04-01
# HARRISON COUNTY COMMUNITY HOSPITAL                    167  2015-07-01
# MACON COUNTY SAMARITAN MEMORIAL HOSPITAL              264  2015-04-01
# HERMANN AREA DISTRICT HOSPITAL                        119  2015-07-01
# MERCY HOSPITAL AURORA                                  96  2015-07-01
# MERCY HOSPITAL CASSVILLE                               98  2015-07-01
# SALEM MEMORIAL DISTRICT HOSPITAL                      339  2015-07-01
# MERCY HOSPITAL LINCOLN                                161  2015-07-01
# LAFAYETTE REGIONAL HEALTH CENTER                      194  2015-07-01
# HEDRICK MEDICAL CENTER                                359  2015-07-01
# EXCELSIOR SPRINGS HOSPITAL                             47  2015-07-01
# CEDAR COUNTY MEMORIAL HOSPITAL                         53  2015-07-01
# CASS REGIONAL MEDICAL CENTER                          289  2015-04-01
# COX BARTON COUNTY HOSPITAL                            201  2015-04-01
# RAY COUNTY MEMORIAL HOSPITAL                          204  2015-07-01
# MOSAIC MEDICAL CENTER ALBANY                          117  2015-07-01
# COX MONETT HOSPITAL                                    98  2015-07-01
# STE GENEVIEVE COUNTY MEMORIAL HOSPITAL                291  2015-04-01
# FREEMAN NEOSHO HOSPITAL                               258  2015-07-01
# CARROLL COUNTY MEMORIAL HOSPITAL                       81  2015-07-01
# PIKE COUNTY MEMORIAL HOSPITAL                         211  2015-07-01
# I-70 COMMUNITY HOSPITAL                                26  2015-07-01
# MERCY ST FRANCIS HOSPITAL                              60  2015-07-01
# IRON COUNTY MEDICAL CENTER                             99  2015-07-01
# MISSOURI BAPTIST SULLIVAN HOSPITAL                    275  2015-07-01
# MERCY HOSPITAL CARTHAGE                               153  2015-07-01
#
#                                                      end_date  days    per_day
# MERCY HOSPITAL JOPLIN                              2018-06-30  1186    25.2757
# COOPER COUNTY COMMUNITY HOSPITAL                   2018-06-30  1095    0.63653
# SSM HEALTH ST JOSEPH HOSPITAL-ST CHARLES           2018-06-30  1186    19.7664
# MOSAIC LIFE CARE AT ST JOSEPH                      2018-06-30  1186    46.2563
# BOTHWELL REGIONAL HEALTH CENTER                    2018-06-30  1186    12.4089
# SSM HEALTH ST. MARY'S HOSPITAL - JEFFERSON CITY    2018-06-30  1186    17.3111
# PHELPS HEALTH                                      2018-06-30  1186    13.5025
# MERCY HOSPITAL ST LOUIS                            2018-06-30  1186    57.8963
# NORTHEAST REGIONAL MEDICAL CENTER                  2018-06-30  1186    6.52277
# MERCY HOSPITAL JEFFERSON                           2018-06-30  1186    20.0422
# TEXAS COUNTY MEMORIAL HOSPITAL                     2018-06-30  1095    3.29589
# HANNIBAL REGIONAL HOSPITAL                         2018-06-30  1186    14.7825
# RESEARCH MEDICAL CENTER                            2018-06-30  1186    27.4148
# BARNES JEWISH HOSPITAL                             2018-06-30  1186    110.719
# BATES COUNTY MEMORIAL HOSPITAL                     2018-06-30  1095    2.84658
# COX MEDICAL CENTERS                                2018-06-30  1186    58.3212
# CAPITAL REGION MEDICAL CENTER                      2018-06-30  1186    14.8381
# TRUMAN MEDICAL CENTER HOSPITAL HILL                2018-06-30  1095    10.7078
# KANSAS CITY VA MEDICAL CENTER                      2018-06-30  1095   0.860274
# MOSAIC MEDICAL CENTER - MARYVILLE                  2018-06-30  1186    2.08853
# MERCY HOSPITAL WASHINGTON                          2018-06-30  1186    11.9519
# CAMERON REGIONAL MEDICAL CENTER                    2018-06-30  1186    5.11467
# MERCY HOSPITAL LEBANON                             2018-06-30  1186    4.77656
# NEVADA REGIONAL MEDICAL CENTER                     2018-06-30  1095     1.8274
# SAINT LUKES NORTH HOSPITAL                         2018-06-30  1186    13.2336
# SSM HEALTH ST. MARY'S HOSPITAL-AUDRAIN             2018-06-30  1186    4.67369
# MERCY HOSPITAL SPRINGFIELD                         2018-06-30  1186    68.5194
# BOONE HOSPITAL CENTER                              2018-06-30  1186    53.2032
# PEMISCOT COUNTY MEMORIAL HOSPITAL                  2018-06-30  1095    3.55342
# MOBERLY REGIONAL MEDICAL CENTER                    2018-06-30  1186    3.25464
# MERCY HOSPITAL SOUTH                               2018-06-30  1186    52.6872
# OZARKS MEDICAL CENTER                              2018-06-30  1186    11.5489
# POPLAR BLUFF VA MEDICAL CENTER                     2018-06-30  1095   0.206393
# SSM HEALTH ST CLARE HOSPITAL - FENTON              2018-06-30  1186    23.6762
# ST JOSEPH MEDICAL CENTER                           2018-06-30  1186    19.0034
# SSM HEALTH ST MARY'S HOSPITAL - ST LOUIS           2018-06-30  1186    22.7639
# COX MEDICAL CENTER BRANSON                         2018-06-30  1186    14.0245
# CENTERPOINT MEDICAL CENTER                         2018-06-30  1186    29.6003
# NORTH KANSAS CITY HOSPITAL                         2018-06-30  1186    51.8094
# WESTERN MISSOURI MEDICAL CENTER                    2018-06-30  1186    6.11636
# ST LOUIS-JOHN COCHRAN VA MEDICAL CENTER            2018-06-30  1095   0.969863
# TRUMAN MEDICAL CENTER LAKEWOOD                     2018-06-30  1186     3.6231
# SSM HEALTH DEPAUL HOSPITAL ST LOUIS                2018-06-30  1186    43.4949
# SSM HEALTH SAINT LOUIS UNIVERSITY HOSPITAL         2018-06-30  1095    27.0594
# MISSOURI BAPTIST MEDICAL CENTER                    2018-06-30  1186    53.0481
# SOUTHEASTHEALTH                                    2018-06-30  1186    28.4671
# MISSOURI DELTA MEDICAL CENTER                      2018-06-30  1186     9.3516
# POPLAR BLUFF REGIONAL MEDICAL CENTER               2018-06-30  1186    21.2192
# FREEMAN HEALTH SYSTEM - FREEMAN WEST               2018-06-30  1186    45.1256
# ST LUKES HOSPITAL OF KANSAS CITY                   2018-06-30  1186    49.3145
# UNIVERSITY OF MISSOURI HEALTH CARE                 2018-06-30  1186    47.6332
# FITZGIBBON HOSPITAL                                2018-06-30  1186    3.09359
# SOUTHEASTHEALTH CENTER OF STODDARD COUNTY          2018-06-30  1095    2.56621
# BARNES-JEWISH WEST COUNTY HOSPITAL                 2018-06-30  1186    8.11298
# PARKLAND HEALTH CENTER                             2018-06-30  1186    8.20489
# GOLDEN VALLEY MEMORIAL HOSPITAL                    2018-06-30  1186    5.36256
# ST LUKE'S DES PERES HOSPITAL                       2018-06-30  1186    11.0809
# LIBERTY HOSPITAL                                   2018-06-30  1186    20.8398
# ST LUKES HOSPITAL                                  2018-06-30  1186    44.6771
# CHRISTIAN HOSPITAL NORTHEAST-NORTHWEST             2018-06-30  1186    26.8516
# SAINT FRANCIS MEDICAL CENTER                       2018-06-30  1186    38.1105
# LAKE REGIONAL HEALTH SYSTEM                        2018-06-30  1186    13.5143
# LEE'S SUMMIT MEDICAL CENTER                        2018-06-30  1186    9.95447
# BARNES-JEWISH ST PETERS HOSPITAL                   2018-06-30  1186    13.2108
# ST MARY'S MEDICAL CENTER                           2018-06-30  1186    11.4755
# CITIZENS MEMORIAL HOSPITAL                         2018-06-30  1186    6.34823
# SSM HEALTH SAINT JOSEPH HOSPITAL-LAKE SAINT LOUIS  2018-06-30  1186    20.4376
# FULTON MEDICAL CENTER LLC                          2018-06-30   729   0.252401
# ST ALEXIUS HOSPITAL                                2018-06-30  1095    5.21644
# BELTON REGIONAL MEDICAL CENTER                     2018-06-30  1186    7.81619
# SAINT LUKE'S EAST HOSPITAL                         2018-06-30  1186    30.2403
# PROGRESS WEST HOSPITAL                             2018-06-30  1186    5.00084
# COLUMBIA MO VA MEDICAL CENTER                      2018-06-30  1095   0.812785
# ELLETT MEMORIAL HOSPITAL                           2018-06-30  1095  0.0885845
# MADISON MEDICAL CENTER                             2018-06-30  1095  0.0940639
# COMMUNITY HOSPITAL ASSOCIATION                     2018-06-30  1095   0.168037
# PUTNAM COUNTY MEMORIAL HOSPITAL                    2018-06-30  1095  0.0648402
# SULLIVAN COUNTY MEMORIAL HOSPITAL                  2018-06-30  1095  0.0365297
# PERSHING MEMORIAL HOSPITAL                         2018-06-30  1095    0.16347
# WASHINGTON COUNTY MEMORIAL HOSPITAL                2018-06-30  1095   0.200913
# WRIGHT MEMORIAL HOSPITAL                           2018-06-30  1095   0.180822
# SCOTLAND COUNTY  HOSPITAL                          2018-06-30  1095   0.106849
# PERRY COUNTY MEMORIAL HOSPITAL                     2018-06-30  1186   0.411467
# HARRISON COUNTY COMMUNITY HOSPITAL                 2018-06-30  1095   0.152511
# MACON COUNTY SAMARITAN MEMORIAL HOSPITAL           2018-06-30  1186   0.222597
# HERMANN AREA DISTRICT HOSPITAL                     2018-06-30  1095   0.108676
# MERCY HOSPITAL AURORA                              2018-06-30  1095  0.0876712
# MERCY HOSPITAL CASSVILLE                           2018-06-30  1095  0.0894977
# SALEM MEMORIAL DISTRICT HOSPITAL                   2018-06-30  1095   0.309589
# MERCY HOSPITAL LINCOLN                             2018-06-30  1095   0.147032
# LAFAYETTE REGIONAL HEALTH CENTER                   2018-06-30  1095   0.177169
# HEDRICK MEDICAL CENTER                             2018-06-30  1095   0.327854
# EXCELSIOR SPRINGS HOSPITAL                         2018-06-30  1095  0.0429224
# CEDAR COUNTY MEMORIAL HOSPITAL                     2018-06-30  1095  0.0484018
# CASS REGIONAL MEDICAL CENTER                       2018-06-30  1186   0.243676
# COX BARTON COUNTY HOSPITAL                         2018-06-30  1186   0.169477
# RAY COUNTY MEMORIAL HOSPITAL                       2018-06-30  1095   0.186301
# MOSAIC MEDICAL CENTER ALBANY                       2018-06-30  1095   0.106849
# COX MONETT HOSPITAL                                2018-06-30  1095  0.0894977
# STE GENEVIEVE COUNTY MEMORIAL HOSPITAL             2018-06-30  1186   0.245363
# FREEMAN NEOSHO HOSPITAL                            2018-06-30  1095   0.235616
# CARROLL COUNTY MEMORIAL HOSPITAL                   2018-06-30  1095  0.0739726
# PIKE COUNTY MEMORIAL HOSPITAL                      2018-06-30  1095   0.192694
# I-70 COMMUNITY HOSPITAL                            2018-06-30  1095  0.0237443
# MERCY ST FRANCIS HOSPITAL                          2018-06-30  1095  0.0547945
# IRON COUNTY MEDICAL CENTER                         2018-06-30  1095   0.090411
# MISSOURI BAPTIST SULLIVAN HOSPITAL                 2018-06-30  1095   0.251142
# MERCY HOSPITAL CARTHAGE                            2018-06-30  1095   0.139726

# %%
assert(mo_summary['days'].sum() == 123718)

assert(mo_summary['per_day'].min() == 0.023744292237442923)
assert(mo_summary['days'].min() == 729)
assert(mo_summary['days'].max() == 1186)

# %% [markdown]
# ## STEP 4: Histogram
#
# <img src="images/step4.png" alt="Histogram" style="width: 300px; float: right; margin-left: 20px; border: 1px solid">
#
# For this step, I want you to plot a histogram to give yourself a better understanding of this new metric we've calculated: how many patients per day have a potential complication.  Looking at the shape and distribution of the data might give us some indication of the hospital volume and quality.  (Don't take this too seriously, though.  We're cutting some important corners.)
#
# A screenshot is included for reference.

# %%
# %matplotlib inline
# Use the built-in Pandas histogram plotting capability to plot a histogram of the `per_day` values.

mo_summary['per_day'].hist()

# %% [markdown]
# ## STEP 5: Rank Order
#
# Now that we see what the distribution looks like, you can tell that most of the `per_day` values are below 20.  There are, however, some outliers up around 100!  Who are those?  Let's rank the data set by the `per_day` value in descending order, examine them, and produce a list of the "top 3" based on this criteria.  That is, who are the top three hospitals based on having the highest `per_day` values.
#
# At the end of this step, put those hospital names in a list called `top_hospitals` and that will be used for testing.  They should be in the order they appear `[#1, #2, #3]`.  That is, if the top hospitals were Mercy (99.3), BJC (97.2), and MoBap (90.1), then you would have `top_hospitals = ['Mercy','BJC','MoBap']`

# %%
# Put your code below and make sure that your final result ends up in the variable `top_hospitals`
# as described in the instructions above.

top_hospitals = []


df = mo_summary.sort_values('per_day', ascending=False)
top_hospitals = [df.index[0],df.index[1],df.index[2]]

# %%
assert(type(top_hospitals) == list)
### BEGIN HIDDEN TESTS
assert(top_hospitals == ['BARNES JEWISH HOSPITAL', 'MERCY HOSPITAL SPRINGFIELD', 'COX MEDICAL CENTERS'])
### END HIDDEN TESTS
