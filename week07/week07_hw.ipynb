# %% [markdown]
# # Week 7 Assignment
#
# This week has been all about getting information off the internet both in structured data formats (CSV, JSON, etc) as well as HTML.  Answer the questions below as instructed.

# %% [markdown]
# ### 31.1 Finding files on the internet
#
# Go to healthdata.gov and find a file that looks interesting to you.  Provide the metadata below that describes the file you located.
#
# The cell below is a "markdown" cell.  Just double-click it to edit the contents and then Shift-Enter to show the content as formatted text.
#
# ---

# %% [markdown]
# **File Name:**  Lead Testing in School Drinking Water Buildings with Lead-Free Plumbing: Compliance Year 2016
#
# **URL to Page:** https://healthdata.gov/dataset/lead-testing-school-drinking-water-buildings-lead-free-plumbing-compliance-year-2016
#
# **Description:** The data presented is a list of buildings for each NYS public school and Boards of Cooperative Educational Services (BOCES) reported as being lead-free for Compliance Year 2016. I think this is interesting because school districts and BOCES are required to report the presence of lead-free buildings to parents, the NYS Department of Health, NY State Education Department, and local health departments for safety purposes which is something I never really knew or thought about how important having a lead-free building was tothe environment.
#
# **URL to Actual File:** https://health.data.ny.gov/api/views/5hbp-c6bb/rows.csv?accessType=DOWNLOAD
#
# **File Format:** CSV file

# %% [markdown]
# ---

# %% [markdown]
# ### 31.2 Use Pandas to load data from internet
#
# Now write a block of code (doesn't need to be in a function) that will load the file using Pandas and describe the shape of the file contents.  I've provided a cell with some comments in it to help get you started.
#
# Pandas documentation for loading data https://pandas.pydata.org/pandas-docs/version/0.23.4/api.html#input-output
#
# Pandas documentation for describing the shape of data https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.shape.html

# %%
import pandas as pd

url = "https://health.data.ny.gov/api/views/5hbp-c6bb/rows.csv?accessType=DOWNLOAD"

dataset = pd.read_csv(url)

df = pd.DataFrame(dataset)

print("This dataset contains the following row and column count, respectively: " + str(df.shape))

dataset
# Out:
# This dataset contains the following row and column count, respectively: (3050, 11)
#                             School District  \
# 0                    BOCES No District Name
# 1                    BOCES No District Name
# 2       GUILDERLAND CENTRAL SCHOOL DISTRICT
# 3           BINGHAMTON CITY SCHOOL DISTRICT
# 4       NEW LEBANON CENTRAL SCHOOL DISTRICT
# ...                                     ...
# 3045              BALDWIN UNION FREE SCHOOL
# 3046              BALDWIN UNION FREE SCHOOL
# 3047  OPPENHEIM-EPHRATAH-ST. JOHNSVILLE CSD
# 3048               SCHENECTADY CITY SCHOOLS
# 3049               LIVERPOOL CENTRAL SCHOOL
#
#                                             School       County  \
# 0         WFL BOCES AT RED JACKET EDUCATION CENTER      Ontario
# 1                          TECH VALLEY HIGH SCHOOL   Rensselaer
# 2                                   GUILDERLAND MS       Albany
# 3                                MAC ARTHUR SCHOOL       Broome
# 4                               WALTER B HOWARD ES     Columbia
# ...                                            ...          ...
# 3045             HASTINGS SCHOOL ADMIN (LEAD ONLY)       Nassau
# 3046                    MILBURN SCHOOL (LEAD ONLY)       Nassau
# 3047                D H ROBBINS SCHOOL (LEAD ONLY)   Montgomery
# 3048          WASHINGTON IRVING EDUCATIONAL CENTER  Schenectady
# 3049  WETZEL ROAD SCHOOL (MIXED GRADES, LEAD ONLY)     Onondaga
#
#                           Building Name Type of Organization      BEDS Code  \
# 0                     www.redjacket.org          BOCES School  431100000000
# 1               Tech Valley High School          BOCES School  499000000801
# 2                                  None         Public School   10802060008
# 3                     MAC ARTHUR SCHOOL         Public School   30200010011
# 4     Walter B Howard Elementary School         Public School  101601040002
# ...                                 ...                   ...           ...
# 3045                               None         Public School  280210030002
# 3046                               None         Public School  280210030006
# 3047                               None         Public School  271201040003
# 3048                               None         Public School  530600010125
# 3049                               None         Public School  421501060007
#
#                 School Street     School City School State School Zip Code  \
# 0               1506 ROUTE 21     SHORTSVILLE           NY           14548
# 1     246 TRICENTENNIAL DRIVE          ALBANY           NY           12203
# 2          6072 STATE FARM RD     GUILDERLAND           NY           12084
# 3             1123 VESTAL AVE      BINGHAMTON           NY           13903
# 4                  1478 RT 20     NEW LEBANON           NY           12125
# ...                       ...             ...          ...             ...
# 3045      960 HASTINGS STREET         BALDWIN           NY           11510
# 3046      2501 MILBURN AVENUE         BALDWIN           NY           11510
# 3047         61 MONROE STREET  ST. JOHNSVILLE           NY           13452
# 3048       422 MUMFORD STREET     SCHENECTADY           NY           12307
# 3049         4246 WETZEL ROAD       LIVERPOOL           NY           13090
#
#      Date Updated
# 0      12/21/2016
# 1      09/25/2018
# 2      11/01/2016
# 3      12/14/2016
# 4      09/26/2018
# ...           ...
# 3045   01/19/2017
# 3046   01/19/2017
# 3047   01/27/2017
# 3048   02/26/2017
# 3049   01/31/2017
#
# [3050 rows x 11 columns]

# %% [markdown]
# ---

# %% [markdown]
# ### 32.1 HTML Basics
#
# HTML is a form of which othere data format we've talked about:
#
# > A) Binary
# >
# > B) eXtensible Markup Language
# >
# > C) JavaScript Object Notation
# >
# > D) HL7 FHIR

# %%
answer321 = "B"

# %% [markdown]
# ### 32.2 Things in HTML
#
# Which of the following is **not** a part of HTML:
#
# > A) element
# >
# > B) tag
# >
# > C) dictionary
# >
# > D) attribute

# %%
answer322 = "C"

# %% [markdown]
# ### 32.3 Parsing HTML in Python
#
# Which of the following packages can be used to extract a table of data from HTML using Python (include all that apply in a list):
#
# > A) lxml
# >
# > B) BeautifulSoup
# >
# > C) Pandas
# >
# > D) fuzzywuzzy

# %%
answer323 = ["A","B","C"]
